# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pyscisci.all as pyscisci

import os
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %matplotlib inline

# set this path to where the MAG database is stored
path2mag = '/home/ajgates/MAG'
path2mag = '/users/hgt6rn/Documents/DataSets/MAG'

mymag = pyscisci.MAG(path2mag, database_extension='hdf', keep_in_memory=False)

# %%
# sometimes you want to focus your analysis on a pre-defined set of publications

# lets load an example subset
publication_list = pd.read_csv('../example_data/focus_publications_example.csv')
publication_list
# Out:
#      PublicationId    Year                        Doi  \
# 0       2607159947  2017.0  10.1016/J.JOI.2017.04.002
# 1       3106261317  2017.0  10.1016/J.JOI.2017.10.001
# 2       3106392307  2017.0  10.1016/J.JOI.2017.04.004
# 3       2593672369  2017.0  10.1016/J.JOI.2017.02.007
# 4       2722577421  2017.0  10.1016/J.JOI.2017.05.021
# ..             ...     ...                        ...
# 102     2745510841  2017.0  10.1016/J.JOI.2017.05.008
# 103     2560973443  2017.0  10.1016/J.JOI.2016.11.006
# 104     2563792373  2017.0  10.1016/J.JOI.2016.11.008
# 105     2550521721  2017.0  10.1016/J.JOI.2016.10.008
# 106     2622565800  2017.0  10.1016/J.JOI.2017.05.012
#
#                                                  Title
# 0    the time dimension of science connecting the p...
# 1    the research production of nations and departm...
# 2    do mathematicians economists and biomedical sc...
# 3    the impact of collaboration and knowledge netw...
# 4    when social scientists disagree comments on th...
# ..                                                 ...
# 102  counting citations generalizing the perry reny...
# 103  partial orders for zero sum arrays with applic...
# 104  can we use google scholar to identify highly c...
# 105  the brazilian scientific output published in j...
# 106  reply to comment on using multi level frontier...
#
# [107 rows x 4 columns]

# %% [markdown]
# # Filtering when you already have the list of Publication Ids

# %%
# getting the full publication information when we already have the publication ids is very easy
# just pass the list into the load function using a filter_dictionary

# but make sure the list of ids is SORTED!!!
full_pub_info = mymag.load_publications(filter_dict={'PublicationId':np.sort(publication_list['PublicationId'].values)})
full_pub_info
# Out:
# Loading Publications:   0%|          | 0/132 [00:00<?, ?it/s]
#          PublicationId    Year    JournalId      FamilyId  \
# 133899      2607159947  2017.0  205292342.0  2.607160e+09
# 290226      3106261317  2017.0  205292342.0  3.106261e+09
# 394705      3106392307  2017.0  205292342.0  3.106392e+09
# 286538      2593672369  2017.0  205292342.0           NaN
# 1828962     2722577421  2017.0  205292342.0           NaN
# ...                ...     ...          ...           ...
# 531419      2745510841  2017.0  205292342.0           NaN
# 1657627     2560973443  2017.0  205292342.0           NaN
# 1754755     2563792373  2017.0  205292342.0  2.563792e+09
# 1756548     2550521721  2017.0  205292342.0  2.724689e+09
# 1822717     2622565800  2017.0  205292342.0           NaN
#
#                                Doi  \
# 133899   10.1016/J.JOI.2017.04.002
# 290226   10.1016/J.JOI.2017.10.001
# 394705   10.1016/J.JOI.2017.04.004
# 286538   10.1016/J.JOI.2017.02.007
# 1828962  10.1016/J.JOI.2017.05.021
# ...                            ...
# 531419   10.1016/J.JOI.2017.05.008
# 1657627  10.1016/J.JOI.2016.11.006
# 1754755  10.1016/J.JOI.2016.11.008
# 1756548  10.1016/J.JOI.2016.10.008
# 1822717  10.1016/J.JOI.2017.05.012
#
#                                                      Title        Date Volume  \
# 133899   the time dimension of science connecting the p...  2017-05-01     11
# 290226   the research production of nations and departm...  2017-11-01     11
# 394705   do mathematicians economists and biomedical sc...  2017-05-01     11
# 286538   the impact of collaboration and knowledge netw...  2017-05-01     11
# 1828962  when social scientists disagree comments on th...  2017-08-01     11
# ...                                                    ...         ...    ...
# 531419   counting citations generalizing the perry reny...  2017-08-01     11
# 1657627  partial orders for zero sum arrays with applic...  2017-02-01     11
# 1754755  can we use google scholar to identify highly c...  2017-02-01     11
# 1756548  the brazilian scientific output published in j...  2017-02-01     11
# 1822717  reply to comment on using multi level frontier...  2017-08-01     11
#
#         Issue FirstPage LastPage DocSubTypes DocType
# 133899      2       608      621                   j
# 290226      4      1142     1157                   j
# 394705      2       598      607                   j
# 286538      2       407      422                   j
# 1828962     3       937      940                   j
# ...       ...       ...      ...         ...     ...
# 531419      3       685      688                   j
# 1657627     1       257      274                   j
# 1754755     1       152      163                   j
# 1756548     1        18       31                   j
# 1822717     3       647      648                   j
#
# [107 rows x 13 columns]

# %% [markdown]
# # Filtering when you have Doi

# %%
# getting the full publication information when we have the publication dois is similarly very easy
# just pass the DOI list into the load function using a filter_dictionary

# but make sure the list of DOIs is SORTED!!!
full_pub_info = mymag.load_publications(filter_dict={'Doi':np.sort(publication_list['Doi'].values)})
full_pub_info
# Out:
# Loading Publications:   0%|          | 0/132 [00:00<?, ?it/s]
#          PublicationId    Year     JournalId      FamilyId  \
# 133898      3106485173  2017.0  2.595727e+09  2.607160e+09
# 133899      2607159947  2017.0  2.052923e+08  2.607160e+09
# 290225      2766136890  2017.0  2.595119e+09  3.106261e+09
# 290226      3106261317  2017.0  2.052923e+08  3.106261e+09
# 394705      3106392307  2017.0  2.052923e+08  3.106392e+09
# ...                ...     ...           ...           ...
# 1657627     2560973443  2017.0  2.052923e+08           NaN
# 1754755     2563792373  2017.0  2.052923e+08  2.563792e+09
# 1754756     3105977400  2018.0  2.595119e+09  2.563792e+09
# 1756548     2550521721  2017.0  2.052923e+08  2.724689e+09
# 1822717     2622565800  2017.0  2.052923e+08           NaN
#
#                                Doi  \
# 133898   10.1016/J.JOI.2017.04.002
# 133899   10.1016/J.JOI.2017.04.002
# 290225   10.1016/J.JOI.2017.10.001
# 290226   10.1016/J.JOI.2017.10.001
# 394705   10.1016/J.JOI.2017.04.004
# ...                            ...
# 1657627  10.1016/J.JOI.2016.11.006
# 1754755  10.1016/J.JOI.2016.11.008
# 1754756  10.1016/J.JOI.2016.11.008
# 1756548  10.1016/J.JOI.2016.10.008
# 1822717  10.1016/J.JOI.2017.05.012
#
#                                                      Title        Date Volume  \
# 133898   the time dimension of science connecting the p...  2017-04-15
# 133899   the time dimension of science connecting the p...  2017-05-01     11
# 290225   the research production of nations and departm...  2017-11-23
# 290226   the research production of nations and departm...  2017-11-01     11
# 394705   do mathematicians economists and biomedical sc...  2017-05-01     11
# ...                                                    ...         ...    ...
# 1657627  partial orders for zero sum arrays with applic...  2017-02-01     11
# 1754755  can we use google scholar to identify highly c...  2017-02-01     11
# 1754756  can we use google scholar to identify highly c...  2018-04-27
# 1756548  the brazilian scientific output published in j...  2017-02-01     11
# 1822717  reply to comment on using multi level frontier...  2017-08-01     11
#
#         Issue FirstPage LastPage DocSubTypes DocType
# 133898                                             r
# 133899      2       608      621                   j
# 290225                                             r
# 290226      4      1142     1157                   j
# 394705      2       598      607                   j
# ...       ...       ...      ...         ...     ...
# 1657627     1       257      274                   j
# 1754755     1       152      163                   j
# 1754756                                            r
# 1756548     1        18       31                   j
# 1822717     3       647      648                   j
#
# [131 rows x 13 columns]

# %% [markdown]
# notice that now we got 131! publications:  this is because a preprint and the journal article may share a doi!
# you will have to decide how to handle this duplication depending on your application

# %% [markdown]
# # Filtering when all you have are the Publication Titles and Years

# %%
# matching by titles is the most computationally expensive, and is greatly assisted by having some additional information
# in this case, we will also use the publication year

# first we have to load the database publication information
# lets just take the journal articles
pub=mymag.load_publications(filter_dict={'DocType':np.sort(['j'])})
pub

# %%
# pyscisci does this filterign using an align_publications function

matched_publication_idx = pyscisci.align_publications(df1 = publication_list, # this should be the information for your subset
                                                   df2=pub, # this is the database publication information
                                                   columns2match_exact=['Year'], # columns you can leverage to match exactly
                                                   column2match_approx='Title', # the column to fuzzy-match on
                                                   ntop=1, # decide if you want only the best match, or (ntop>1) also include near matches
                                                   cosine_lower_bound=0.75, # a rough matching first, threshold 0-1
                                                    use_threads=True, # parrelize?
                                                   n_jobs=10, # number of workers
                                                   lev_lower_bound=0.9, # the finer matching, threhold 0-1
                                                   show_progress=False)

# the returned array gives the indices of the match
matched_publication_idx
# Out:
# array([  719149.,  1436395.,  2150638.,  4160284.,  4670599.,  6395332.,
#         6786035., 10108126., 10719680., 11737951., 12524311., 13113938.,
#        13179952., 14583062., 15343815., 17422892., 18157598., 18207365.,
#        18921116., 20349831., 21032010., 21111275., 21518535., 21776916.,
#        22918351., 23203324., 23205803., 23251257., 23560332., 23882133.,
#        54793508., 26566541., 26650188., 27486281., 28249189., 28917739.,
#        28959166., 29186556., 29765315., 29854507., 30347157., 31058195.,
#        31552769., 31927753., 32012664., 33600012., 33870115., 35352421.,
#        35413714., 35696570., 35831995., 39264690., 40566544., 41479708.,
#        43594349., 43906973., 44261803., 44893363., 45158315., 46402512.,
#        48093997., 48109252., 48363807., 48504715., 50114030., 50436226.,
#        51860207., 52468527., 53182512., 55472308., 56442946., 56603799.,
#        57097898., 58930017., 59252407., 60085395., 60657401., 60679605.,
#        61395154., 61960282., 62248856., 64105716., 64962111., 65588386.,
#        68220639., 70359306., 71484911., 72815706., 73170710., 73886699.,
#        74242358., 74597274., 75501481., 75981850., 77810573., 78403087.,
#        79973031., 80308209., 80529893., 80582863., 82091013., 82094359.,
#        82238075., 85325307., 86730593., 86730856., 88788087.])

# %%
# to recover the full information, we need to index into the publication dataframe
matched_publications = pub.iloc[matched_publication_idx]
matched_publications
# Out:
#           PublicationId    Year    JournalId      FamilyId  \
# 719149       2607159947  2017.0  205292342.0  2.607160e+09
# 1436395      3106261317  2017.0  205292342.0  3.106261e+09
# 2150638      3106392307  2017.0  205292342.0  3.106392e+09
# 4160284      2593672369  2017.0  205292342.0           NaN
# 4670599      2722577421  2017.0  205292342.0           NaN
# ...                 ...     ...          ...           ...
# 82238075     2745510841  2017.0  205292342.0           NaN
# 85325307     2560973443  2017.0  205292342.0           NaN
# 86730593     2563792373  2017.0  205292342.0  2.563792e+09
# 86730856     2550521721  2017.0  205292342.0  2.724689e+09
# 88788087     2622565800  2017.0  205292342.0           NaN
#
#                                 Doi  \
# 719149    10.1016/J.JOI.2017.04.002
# 1436395   10.1016/J.JOI.2017.10.001
# 2150638   10.1016/J.JOI.2017.04.004
# 4160284   10.1016/J.JOI.2017.02.007
# 4670599   10.1016/J.JOI.2017.05.021
# ...                             ...
# 82238075  10.1016/J.JOI.2017.05.008
# 85325307  10.1016/J.JOI.2016.11.006
# 86730593  10.1016/J.JOI.2016.11.008
# 86730856  10.1016/J.JOI.2016.10.008
# 88788087  10.1016/J.JOI.2017.05.012
#
#                                                       Title        Date  \
# 719149    the time dimension of science connecting the p...  2017-05-01
# 1436395   the research production of nations and departm...  2017-11-01
# 2150638   do mathematicians economists and biomedical sc...  2017-05-01
# 4160284   the impact of collaboration and knowledge netw...  2017-05-01
# 4670599   when social scientists disagree comments on th...  2017-08-01
# ...                                                     ...         ...
# 82238075  counting citations generalizing the perry reny...  2017-08-01
# 85325307  partial orders for zero sum arrays with applic...  2017-02-01
# 86730593  can we use google scholar to identify highly c...  2017-02-01
# 86730856  the brazilian scientific output published in j...  2017-02-01
# 88788087  reply to comment on using multi level frontier...  2017-08-01
#
#          Volume Issue FirstPage LastPage DocSubTypes DocType
# 719149       11     2       608      621                   j
# 1436395      11     4      1142     1157                   j
# 2150638      11     2       598      607                   j
# 4160284      11     2       407      422                   j
# 4670599      11     3       937      940                   j
# ...         ...   ...       ...      ...         ...     ...
# 82238075     11     3       685      688                   j
# 85325307     11     1       257      274                   j
# 86730593     11     1       152      163                   j
# 86730856     11     1        18       31                   j
# 88788087     11     3       647      648                   j
#
# [107 rows x 13 columns]
